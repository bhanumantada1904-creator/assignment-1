# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanumantada1904-creator/assignment-1/blob/main/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def name(player_name):
    games_played =int (input("number of the games_player"))
    total_score =int (input("enter the total score acheived"))
    if games_played > 0:
        average_score = total_score/games_played
    else:
        average_score = 0
    print(f"player:{player_name}")
    print(f"games player:{games_played}")
    print(f"total score:{total_score}")
    return average_score

# Calling the function to demonstrate its execution
name("Sample Player")

# %%
def name(bhanu):
    games_played =int (input("4"))
    total_score =int (input("450"))
    if games_played > 0:
        average_score = total_score / games_played
    else:
        average_score = 0
    print(f"player: {bhanu}")
    print(f"games played: {games_played}")
    print(f"total score: {total_score}")
    return average_score
